# %% [markdown]
# <a href="https://colab.research.google.com/github/Beta628427/TRADE/blob/master/Lectura_cod_fuente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install httplib2

# %%
import urllib.request
datos = urllib.request.urlopen('https://es.tradingview.com/chart/').read().decode()

# %%
pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
soup =  BeautifulSoup(datos)
tags = soup('script')
for tag in tags:
	print(tag.get('href'))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(datos)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="is-not-authenticated is-not-pro is-not-trial " dir="ltr" lang="es">
#  <head>
#   <!--[if lt IE 10]>
# 	<script type="text/javascript">
# 		if (String(window.location).search('badbrowser') === -1) {
# 			window.location = "/badbrowser/";
# 		}
# 	</script>
# 	<![endif]-->
#   <script nonce="fTyemGO4NnOJENVf">
#    var environment = 'battle';
# 		window.WS_HOST_PING_REQUIRED = true;
# 		window.WEBSOCKET_HOST = 'data.tradingview.com';
# 		window.WEBSOCKET_PRO_HOST = 'prodata.tradingview.com';
# 		window.WEBSOCKET_PORT = '';
# 		window.TradingView = window.TradingView || {};
#
# 	TradingView.onChartPage = true;
#   </script>
#   <script nonce="fTyemGO4NnOJENVf">
# ...

# %%
from bs4 import BeautifulSoup
soup =  BeautifulSoup(datos)
tags = soup('script')
tags
# Out:
# [<script nonce="fTyemGO4NnOJENVf">
#  		var environment = 'battle';
#  		window.WS_HOST_PING_REQUIRED = true;
#  		window.WEBSOCKET_HOST = 'data.tradingview.com';
#  		window.WEBSOCKET_PRO_HOST = 'prodata.tradingview.com';
#  		window.WEBSOCKET_PORT = '';
#  		window.TradingView = window.TradingView || {};
#
#  	TradingView.onChartPage = true;
#  	</script>, <script nonce="fTyemGO4NnOJENVf">
# ...
